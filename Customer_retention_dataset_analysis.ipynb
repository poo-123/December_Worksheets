# %%
# Data Analysis Phase
# Main aim to understand about the data

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
## Display all the columns of the dataframe

pd.pandas.set_option('display.max_columns',None)

# %%
dataset=pd.read_csv('customer_retention_dataset.csv')


## print shape of dataset with rows and columns
print(dataset.shape)
# Out:
# (269, 71)

# %%
## print the top5 records

dataset.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %% [markdown]
# ### Missing Values

# %%
## Here we will check the percentage of nan values present in each feature
## 1 -step make the list of features which has missing values

features_with_na=[features for features in dataset.columns if dataset[features].isnull().sum()>1]

## 2- step print the feature name and the percentage of missing values

for features in features_with_na:
    print(features, np.round(dataset[feature].isnull().mean(), 4),  ' % missing values')

# %%
dataset.isnull().sum()
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %% [markdown]
# #### Dataset has no missing values

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                          --------------  -----
#  0   1Gender of respondent                                                                                                                                                                                           269 non-null    object
# ...

# %% [markdown]
# ## Numerical Variables

# %%
# list of numerical variables
numerical_features = [feature for feature in dataset.columns if dataset[feature].dtypes != 'O']

print('Number of numerical variables: ', len(numerical_features))

# visualise the numerical variables
dataset[numerical_features].head()
# Out:
# Number of numerical variables:  1
#    4 What is the Pin Code of where you shop online from?
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068

# %%
plt.figure(figsize=(15,5))
sns.countplot(dataset['4 What is the Pin Code of where you shop online from?'])
plt.xticks(rotation=90)
plt.show()

# %% [raw]
# As we see the graph the customers from the pin no 201308 are more active in shopping online products where as cutomers from pin nos 2033002, 203207 and 560001 are least inetrested in online shopp9ng

# %% [markdown]
# ## Categorical Variables

# %%
categorical_features=[feature for feature in dataset.columns if data[feature].dtypes=='O']
categorical_features
# Out:
# ['1Gender of respondent',
#  '2 How old are you? ',
#  '3 Which city do you shop online from?',
#  '5 Since How Long You are Shopping Online ?',
#  '6 How many times you have made an online purchase in the past 1 year?',
#  '7 How do you access the internet while shopping on-line?',
#  '8 Which device do you use to access the online shopping?',
#  '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#  '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#  '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#  '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
#  '13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   ',
# ...

# %%
dataset[categorical_features].head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# 1                              Above 4 years
# 2                                  3-4 years
# 3                                  3-4 years
# 4                                  2-3 years
#
#   6 How many times you have made an online purchase in the past 1 year?  \
# 0                                        31-40 times
# ...

# %%
for feature in categorical_features:
    print('The feature is {} and number of categories are {}'.format(feature,len(dataset[feature].unique())))
# Out:
# The feature is 1Gender of respondent and number of categories are 2
# The feature is 2 How old are you?  and number of categories are 5
# The feature is 3 Which city do you shop online from? and number of categories are 11
# The feature is 5 Since How Long You are Shopping Online ? and number of categories are 5
# The feature is 6 How many times you have made an online purchase in the past 1 year? and number of categories are 6
# The feature is 7 How do you access the internet while shopping on-line? and number of categories are 4
# The feature is 8 Which device do you use to access the online shopping? and number of categories are 4
# The feature is 9 What is the screen size of your mobile device?						                                         and number of categories are 4
# The feature is 10 What is the operating system (OS) of your device?				                                           and number of categories are 3
# ...

# %%
for feature in categorical_features:
    data=dataset.copy()
    data.groupby(feature)['4 What is the Pin Code of where you shop online from?'].median().plot.bar()
    plt.xlabel(feature)
    plt.ylabel('4 What is the Pin Code of where you shop online from?')
    plt.title(feature)
    plt.show()

# %%
categorical_features=[feature for feature in dataset.columns if dataset[feature].dtype=='O']

# %%
categorical_features
# Out:
# ['1Gender of respondent',
#  '2 How old are you? ',
#  '3 Which city do you shop online from?',
#  '5 Since How Long You are Shopping Online ?',
#  '6 How many times you have made an online purchase in the past 1 year?',
#  '7 How do you access the internet while shopping on-line?',
#  '8 Which device do you use to access the online shopping?',
#  '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#  '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#  '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#  '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
#  '13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   ',
# ...

# %%
for feature in categorical_features:
    temp=dataset.groupby(feature)['4 What is the Pin Code of where you shop online from?'].count()/len(dataset)
    temp_df=temp[temp>0.01].index
    dataset[feature]=np.where(dataset[feature].isin(temp_df),dataset[feature],'Rare_var')

# %%
dataset.head(10)
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
# 5                Female         31-40 years
# 6                  Male         41-50 yaers
# 7                  Male         41-50 yaers
# 8                Female  Less than 20 years
# 9                Female         31-40 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
# 5                                 Noida
# 6                                 Delhi
# 7                                 Delhi
# 8                                 Solan
# 9                                 Delhi
#
# ...

# %%
for feature in categorical_features:
    labels_ordered=dataset.groupby([feature])['4 What is the Pin Code of where you shop online from?'].mean().sort_values().index
    labels_ordered={k:i for i,k in enumerate(labels_ordered,0)}
    dataset[feature]=dataset[feature].map(labels_ordered)

# %%
dataset.head(10)
# Out:
#    1Gender of respondent  2 How old are you?   \
# 0                      0                    0
# 1                      1                    4
# 2                      1                    4
# 3                      0                    4
# 4                      1                    4
# 5                      1                    0
# 6                      0                    3
# 7                      0                    3
# 8                      1                    1
# 9                      1                    0
#
#    3 Which city do you shop online from?  \
# 0                                      0
# 1                                      0
# 2                                      6
# 3                                      2
# 4                                     10
# 5                                      5
# 6                                      0
# 7                                      0
# 8                                      3
# ...

# %%
scaling_feature=[feature for feature in dataset.columns if feature not in ['4 What is the Pin Code of where you shop online from?'] ]
len(scaling_feature)
# Out:
# 70

# %%
scaling_feature
# Out:
# ['1Gender of respondent',
#  '2 How old are you? ',
#  '3 Which city do you shop online from?',
#  '5 Since How Long You are Shopping Online ?',
#  '6 How many times you have made an online purchase in the past 1 year?',
#  '7 How do you access the internet while shopping on-line?',
#  '8 Which device do you use to access the online shopping?',
#  '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#  '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#  '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#  '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
#  '13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   ',
# ...

# %%
dataset.head()
# Out:
#    1Gender of respondent  2 How old are you?   \
# 0                      0                    0
# 1                      1                    4
# 2                      1                    4
# 3                      0                    4
# 4                      1                    4
#
#    3 Which city do you shop online from?  \
# 0                                      0
# 1                                      0
# 2                                      6
# 3                                      2
# 4                                     10
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#    5 Since How Long You are Shopping Online ?  \
# 0                                           2
# ...

# %% [markdown]
# ## Feature Scaling

# %%
feature_scale=[feature for feature in dataset.columns if feature not in ['4 What is the Pin Code of where you shop online from?']]

from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
scaler.fit(dataset[feature_scale])
# Out:
# MinMaxScaler()

# %%
scaler.transform(dataset[feature_scale])
# Out:
# array([[0.        , 0.        , 0.        , ..., 0.57142857, 0.85714286,
#         0.57142857],
#        [1.        , 1.        , 0.        , ..., 0.14285714, 0.42857143,
#         1.        ],
#        [1.        , 1.        , 0.6       , ..., 0.42857143, 0.85714286,
#         0.42857143],
#        ...,
#        [1.        , 0.75      , 1.        , ..., 0.85714286, 0.85714286,
#         0.71428571],
#        [1.        , 0.25      , 0.3       , ..., 0.28571429, 0.28571429,
#         0.71428571],
#        [1.        , 0.75      , 0.4       , ..., 0.57142857, 0.85714286,
#         0.71428571]])
